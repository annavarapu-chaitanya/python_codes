# %%
# Replace all occurrences of "a" with "@" in a given string.
s = input("Enter a string: ")
print(s.replace("a", "@"))
# Out:
# Enter a string:  chaitu@nya
# ch@itu@ny@

# %%
# Write a program to print the first and last character of a given string.
s = input("Enter a string: ")
print("First character:", s[0])
print("Last character:", s[-1])
# Out:
# Enter a string:  chaitanya
# First character: c
# Last character: a

# %%
# Write a program to convert a string to uppercase and lowercase.
s = input("Enter a string: ")
print("Uppercase:", s.upper())
print("Lowercase:", s.lower())
# Out:
# Enter a string:  chaitanya
# Uppercase: CHAITANYA
# Lowercase: chaitanya

# %%
# Write a program to remove all spaces from a given string.
s = input("Enter a string: ")
print(s.replace(" ", ""))
# Out:
# Enter a string:  chaitanya
# chaitanya

# %%
# Check if the word "Python" exists in the given sentence. 
s = input("Enter a sentence: ")

if "Python" in s:
    print("Found")
else:
    print("Not Found")
# Out:
# Enter a sentence:  orange army
# Not Found

# %%
# Check if the word "Python" exists in the given sentence. 
s = input("Enter a sentence: ")

if "Python" in s:
    print("Found")
else:
    print("Not Found")
# Out:
# Enter a sentence:  Python
# Found

# %%
# Print the first three characters of a given string.
s = input("Enter a string: ")
print(s[:3])
# Out:
# Enter a string:  thanaya
# tha

# %%
# Take two strings as input and merge them.
s1 = input("Enter first string: ")
s2 = input("Enter second string: ")

print(s1 + s2)
# Out:
# Enter first string:  I am orange army
# Enter second string:  i am the fan of srh
# I am orange armyi am the fan of srh

# %%
# Write a program to check if a string contains only numbers.
s = input("Enter a string: ")

if s.isdigit():
    print("Only numbers")
else:
    print("Contains other characters")
# Out:
# Enter a string:  89
# Only numbers

# %%
# Write a program to check if a string contains only numbers.
s = input("Enter a string: ")

if s.isdigit():
    print("Only numbers")
else:
    print("Contains other characters")
# Out:
# Enter a string:  chaitu
# Contains other characters

# %%
# Remove all occurrences of "e" from a string.
s = input("Enter a string: ")
print(s.replace("e", ""))
# Out:
# Enter a string:  alphabt
# alphabt

# %%
# Count how many times the letter 'o' appears in a given string.
s = input("Enter a string: ")
print(s.count("o"))
# Out:
# Enter a string:  i studied in guntur
# 0

# %%
# Check if a username contains only letters and numbers
username = input("Enter username: ")

if username.isalnum():
    print("Valid Username")
else:
    print("Invalid Username")
# Out:
# Enter username:  chaitanya
# Valid Username

# %%
# An email has "@" and ends with ".com".
email = input("Enter email: ")

if "@" in email and email.endswith(".com"):
    print("Valid Email")
else:
    print("Invalid Email")
# Out:
# Enter email:  chaitanya12603@gmail.com
# Valid Email

# %%
# Write a program to find the length of a given string without using len().
s = input("Enter a string: ")

count = 0
for ch in s:
    count += 1

print("Length:", count)
# Out:
# Enter a string:  i studied in vvit
# Length: 17

# %%
# Write a Python program to reverse a given string.
s = input("Enter a string: ")
print(s[::-1])
# Out:
# Enter a string:  chaitanya
# aynatiahc

# %%
# Count Vowels in a String
s = input("Enter a string: ")

count = 0

for ch in s.lower():
    if ch in "aeiou":
        count += 1

print("Vowels:", count)
# Out:
# Enter a string:  chaitanya
# Vowels: 4

# %%
# Count consonants in a string
s = input("Enter a string: ")

count = 0

for ch in s.lower():
    if ch.isalpha() and ch not in "aeiou":
        count += 1

print("Consonants:", count)
# Out:
# Enter a string:  chaitanya
# Consonants: 5
