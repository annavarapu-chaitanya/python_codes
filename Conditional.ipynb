# %%
## Write a program to check if a number is greater than 10.
number = int(input('Enter Number: '))

if number > 10:
    print('Your number is greater than 10')
# Out:
# Enter Number:  22
# Your number is greater than 10

# %%
# Write a program to check if a person is eligible to vote (age 18 or above)
age = int(input("Enter your age: "))

if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")
# Out:
# Enter your age:  23
# You are eligible to vote.

# %%
# Write a program to check if a number is positive.
num = int(input("Enter a number: "))

if num > 0:
    print("The number is positive.")
else:
    print("The number is not positive.")
# Out:
# Enter a number:  3
# The number is positive.

# %%
# Write a program to check if a number is even or odd.
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("The number is even.")
else:
    print("The number is odd.")
# Out:
# Enter a number:  9
# The number is odd.

# %%
# Write a program to check if a person is eligible for a driving license (age 18 or above).
age = int(input("Enter your age: "))

if age >= 18:
    print("You are eligible for a driving license.")
else:
    print("You are not eligible for a driving license.")
# Out:
# Enter your age:  16
# You are not eligible for a driving license.

# %%
# Write a program to check if a number is positive or negative.
num = int(input("Enter a number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a number:  8
# Positive

# %%
# Write a program to check if a number is positive or negative.
num = int(input("Enter a number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a number:  -7
# Negative

# %%
# Write a program to check if a student passed or failed based on marks (Pass: 40+, Fail: below 40).
marks = int(input("Enter your marks: "))

if marks >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter your marks:  35
# Fail

# %%
# Write a program to check if a student passed or failed based on marks (Pass: 40+, Fail: below 40).
marks = int(input("Enter your marks: "))

if marks >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter your marks:  60
# Pass

# %%
# Write a program to classify a number as positive, negative, or zero.
num = int(input("Enter a number: "))

if num > 0:
    print("Positive Number")
elif num < 0:
    print("Negative Number")
else:
    print("Zero")
# Out:
# Enter a number:  20
# Positive Number

# %%
# Write a program to classify a number as positive, negative, or zero.
num = int(input("Enter a number: "))

if num > 0:
    print("Positive Number")
elif num < 0:
    print("Negative Number")
else:
    print("Zero")
# Out:
# Enter a number:  -10
# Negative Number

# %%
# Write a program to categorize a person’s age as a child (0-12), teenager (13-19), or adult (20+).
age = int(input("Enter your age: "))

if age >= 0 and age <= 12:
    print("Child")
elif age >= 13 and age <= 19:
    print("Teenager")
elif age >= 20:
    print("Adult")
else:
    print("Invalid Age")
# Out:
# Enter your age:  16
# Teenager

# %%
# Write a program to categorize a person’s age as a child (0-12), teenager (13-19), or adult (20+).
age = int(input("Enter your age: "))

if age >= 0 and age <= 12:
    print("Child")
elif age >= 13 and age <= 19:
    print("Teenager")
elif age >= 20:
    print("Adult")
else:
    print("Invalid Age")
# Out:
# Enter your age:  10
# Child

# %%
# Write a program to determine the grade of a student based on marks (A: 90+, B: 80+, C: 70+, D: 60+, Fail: <40).
marks = int(input("Enter marks: "))

if marks >= 90:
    print("Grade A")
elif marks >= 80:
    print("Grade B")
elif marks >= 70:
    print("Grade C")
elif marks >= 60:
    print("Grade D")
elif marks >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter marks:  35
# Fail

# %%
# Write a program to determine the grade of a student based on marks (A: 90+, B: 80+, C: 70+, D: 60+, Fail: <40).
marks = int(input("Enter marks: "))

if marks >= 90:
    print("Grade A")
elif marks >= 80:
    print("Grade B")
elif marks >= 70:
    print("Grade C")
elif marks >= 60:
    print("Grade D")
elif marks >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter marks:  55
# Pass

# %%
### A bank checks if a person is eligible for a loan based on their age and salary.
age = int(input("Enter your age: "))
salary = int(input("Enter your monthly salary: "))

if age < 21:
    print("Not eligible: Age must be at least 21.")
elif salary < 25000:
    print("Not eligible: Salary is too low.")
else:
    print("Eligible for a loan.")
# Out:
# Enter your age:  33
# Enter your monthly salary:  20000
# Not eligible: Salary is too low.

# %%
# A student needs at least 35 marks to pass. If they score above 90, they get a scholarship.
marks = int(input("Enter your marks: "))

if marks > 90:
    print("Pass")
    print("You got a scholarship.")
elif marks >= 35:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter your marks:  66
# Pass

# %%
# A student needs at least 35 marks to pass. If they score above 90, they get a scholarship.
marks = int(input("Enter your marks: "))

if marks > 90:
    print("Pass")
    print("You got a scholarship.")
elif marks >= 35:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter your marks:  25
# Fail

# %%
# Scenario: A system checks if a user is eligible for a senior citizen discount (age ≥ 60).
# Write a program that takes a person's age as input and prints "Eligible for discount" if they are 60 or older.
age = int(input("Enter your age: "))

if age >= 60:
    print("Eligible for discount")
else:
    print("Not eligible for discount")
# Out:
# Enter your age:  66
# Eligible for discount

# %%
# Scenario: A system checks if a user is eligible for a senior citizen discount (age ≥ 60).
# Write a program that takes a person's age as input and prints "Eligible for discount" if they are 60 or older.
age = int(input("Enter your age: "))

if age >= 60:
    print("Eligible for discount")
else:
    print("Not eligible for discount")
# Out:
# Enter your age:  33
# Not eligible for discount

# %%
# Scenario: A shopping site offers free shipping for orders above ₹500.
# Write a program that takes the total bill amount as input. If it's above ₹500, print "Free Shipping", otherwise print "Shipping Charges Applied".
bill = float(input("Enter bill amount: "))

if bill > 500:
    print("Free Shipping")
else:
    print("Shipping Charges Applied")
# Out:
# Enter bill amount:  500
# Shipping Charges Applied

# %%
# Scenario: A shopping site offers free shipping for orders above ₹500.
# Write a program that takes the total bill amount as input. If it's above ₹500, print "Free Shipping", otherwise print "Shipping Charges Applied".
bill = float(input("Enter bill amount: "))

if bill > 500:
    print("Free Shipping")
else:
    print("Shipping Charges Applied")
# Out:
# Enter bill amount:  600
# Free Shipping

# %%
# Scenario: A system classifies water usage based on liters used.
# Write a program that takes the number of liters used as input.
# If usage is less than 100 liters, print "Low usage".
# If usage is between 100 and 500 liters, print "Moderate usage".
# If usage is above 500 liters, print "High usage".
liters = int(input("Enter water usage in liters: "))

if liters < 100:
    print("Low usage")
elif liters <= 500:
    print("Moderate usage")
else:
    print("High usage")
# Out:
# Enter water usage in liters:  50
# Low usage

# %%
# Scenario: A system classifies water usage based on liters used.
# Write a program that takes the number of liters used as input.
# If usage is less than 100 liters, print "Low usage".
# If usage is between 100 and 500 liters, print "Moderate usage".
# If usage is above 500 liters, print "High usage".
liters = int(input("Enter water usage in liters: "))

if liters < 100:
    print("Low usage")
elif liters <= 500:
    print("Moderate usage")
else:
    print("High usage")
# Out:
# Enter water usage in liters:  100
# Moderate usage

# %%
# Scenario: A movie booking system checks age and ticket availability.
# Write a program that asks for a person's age and checks if tickets are available.
# If the person is 18 or older, check if seats are available:
# If seats are available, print "Booking Confirmed".
# Otherwise, print "Tickets Sold Out".
# If the person is under 18, print "Not eligible for this movie".
age = int(input("Enter age: "))
seats_available = input("Are seats available? (yes/no): ")

if age >= 18:
    if seats_available.lower() == "yes":
        print("Booking Confirmed")
    else:
        print("Tickets Sold Out")
else:
    print("Not eligible for this movie")
# Out:
# Enter age:  55
# Are seats available? (yes/no):  yes
# Booking Confirmed

# %%
# Scenario: A movie booking system checks age and ticket availability.
# Write a program that asks for a person's age and checks if tickets are available.
# If the person is 18 or older, check if seats are available:
# If seats are available, print "Booking Confirmed".
# Otherwise, print "Tickets Sold Out".
# If the person is under 18, print "Not eligible for this movie".
age = int(input("Enter age: "))
seats_available = input("Are seats available? (yes/no): ")

if age >= 18:
    if seats_available.lower() == "yes":
        print("Booking Confirmed")
    else:
        print("Tickets Sold Out")
else:
    print("Not eligible for this movie")
# Out:
# Enter age:  12
# Are seats available? (yes/no):  no
# Not eligible for this movie
